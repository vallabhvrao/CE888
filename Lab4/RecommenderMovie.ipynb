# %%
import pandas as pd
import numpy as np
import operator

# %%
df0 = pd.ExcelFile('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')

# %%
df0.sheet_names
# Out:
# ['Items', 'Users']

# %%
df_Items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true',sheet_name='Items',index_col=None)

# %%
df_Items.head()
# Out:
#    Movie ID  ...  Factor15
# 0        11  ... -0.248806
# 1        12  ...  1.274993
# 2        13  ... -0.419092
# 3        14  ... -0.681191
# 4        22  ... -2.292566
#
# [5 rows x 17 columns]

# %%
df_Users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true',sheet_name='Users', index_col=None)

# %%
df_Users.head()
# Out:
#    User   Factor1   Factor2   Factor3  ...  Factor12  Factor13  Factor14  Factor15
# 0  4768 -0.204024  0.161079 -0.090447  ...  0.355404  0.007108 -0.118663 -0.039125
# 1   156 -0.189652 -0.178979 -0.091490  ... -0.048606  0.045916  0.113671  0.179873
# 2  5323 -0.115308 -0.090886 -0.053129  ... -0.019460  0.108372  0.054471 -0.109552
# 3   174 -0.227462 -0.272532 -0.017231  ... -0.082396  0.036767 -0.165438  0.050692
# 4  4529 -0.014616 -0.102218 -0.107935  ... -0.132836 -0.039897  0.129063  0.102669
#
# [5 rows x 16 columns]

# %%
df_Users.shape, df_Items.shape
# Out:
# ((25, 16), (100, 17))

# %%
# Which 3 movies would you recommend to User 174?
# user with ID 5338 will give to the movie with ID 155.
num_factors = df_Users.shape[1]-1
user_pref = df_Users[df_Users['User'] == 3878].iloc[:, -num_factors:].values[0]
item_feat = df_Items.iloc[:, -num_factors:].values

# %%
df_Items[df_Items['Movie ID']==1892].index.values[0]
# Out:
# 78

# %%
#user with ID 5338 will give to the movie with ID 155
# data.iloc[[0,3,6,24], [0,5,6]]
# df = df_Items.iloc[list(pd.DataFrame(preference).index)]
# item_feat=df_Items.iloc[[21], -num_factors:].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-260141e23ce5> in <module>()
#       1 #user with ID 5338 will give to the movie with ID 155
# ----> 2 data.iloc[[0,3,6,24], [0,5,6]]
#       3 df = df_Items.iloc[list(pd.DataFrame(preference).index)]
#       4 item_feat=df_Items.iloc[[21], -num_factors:].values
#
# NameError: name 'data' is not defined

# %%
preference = item_feat.dot(user_pref)
preference
# Out:
# array([ 6.19344289e-01,  3.96214053e-01,  2.05783903e-01, -7.84492732e-02,
#        -6.86051968e-01,  2.21596664e-01,  7.34459876e-02,  1.54849873e-01,
#         4.23937185e-01,  7.74292199e-01,  1.36075867e-01,  9.28982787e-01,
#         3.26437210e-01, -6.53104828e-02, -1.99243282e+00, -2.06115001e+00,
#        -1.98016804e+00,  1.36740227e-01,  1.99943831e-01, -5.59330427e-01,
#        -1.30809249e-01,  8.44621440e-01,  3.21202545e-02, -2.48359887e-01,
#        -1.13856770e-01, -1.38316511e-01,  3.69218542e-02,  4.17017992e-01,
#         7.02340327e-02,  1.00538903e-02,  6.04942393e-01,  3.37497508e-01,
#         4.16055713e-01, -4.36375511e-02, -4.30571644e-01,  2.85558801e-01,
#         5.12009984e-02,  2.16029584e-01,  6.75617613e-01, -1.44503042e-01,
#        -8.00315450e-01,  5.06230192e-01,  2.28385453e-01,  1.71298864e-01,
#         4.29220331e-02,  5.62888471e-01,  4.71274794e-01, -9.66949811e-01,
#        -6.05956766e-02, -3.37117752e-01, -6.43111172e-03,  1.89960407e-01,
#         2.02102325e-02,  6.70933306e-01, -1.23451297e+00,  3.64138542e-01,
#        -1.77105192e-01, -8.28610630e-04,  8.74464901e-01,  4.10669686e-01,
#        -1.87043467e-02, -2.56986911e-01, -8.45814680e-02,  3.63791049e-01,
#         1.29306190e-01, -3.76226986e-01, -5.55635620e-01,  1.93396049e-01])

# %%
pd.DataFrame(preference).head(20)
# Out:
#            0
# 0   0.619344
# 1   0.396214
# 2   0.205784
# 3  -0.078449
# 4  -0.686052
# 5   0.221597
# 6   0.073446
# 7   0.154850
# 8   0.423937
# 9   0.774292
# 10  0.136076
# 11  0.928983
# 12  0.326437
# 13 -0.065310
# 14 -1.992433
# 15 -2.061150
# 16 -1.980168
# 17  0.136740
# 18  0.199944
# 19 -0.559330

# %%
#values = [zip(df_Users.columns[1:], preference[i]) for i in range(preference.shape[0])]
top_values = pd.DataFrame(preference).nlargest(3, 0)
top_indices = top_values.index
list(top_indices)
#comparison_data.columns = df_Users.columns
# Out:
# [11, 90, 21]

# %%
df_Items.iloc[list(top_indices)]
# Out:
#     Movie ID                      Title   Factor1  ...  Factor13  Factor14  Factor15
# 11       105  Back to the Future (1985) -1.107666  ... -0.582166 -0.757412  0.118024
# 90      8467       Dumb & Dumber (1994)  2.720287  ... -1.240696  0.279910  1.616338
# 21       155     The Dark Knight (2008) -2.169359  ...  2.193465  0.720142  0.445634
#
# [3 rows x 17 columns]

# %%
#quiz number 5
##Factor4 for the movie with ID=22

df_Fator = df_Items[['Movie ID','Factor1']]

value = df_Fator[df_Fator['Movie ID']==9802]['Factor1'].values[0]

round(value,3)
# Out:
# -0.005

# %%
#quiz number 6
#with the lowest loading of factor 7

df_factor2 = df_Items[['Movie ID','Factor1','Title']]
df_factor2.sort_values('Factor1')
# Out:
#     Movie ID   Factor1                                              Title
# 50       603 -3.063639                                  The Matrix (1999)
# 33       278 -2.780308                    The Shawshank Redemption (1994)
# 27       238 -2.611462                               The Godfather (1972)
# 59       680 -2.382739                                Pulp Fiction (1994)
# 16       122 -2.271110  The Lord of the Rings: The Return of the King ...
# ..       ...       ...                                                ...
# 68       854  2.263142                                    The Mask (1994)
# 90      8467  2.720287                               Dumb & Dumber (1994)
# 85      3049  2.723720                  Ace Ventura: Pet Detective (1994)
# 37       414  3.111997                              Batman Forever (1995)
# 86      4327  4.023815                            Charlie's Angels (2000)
#
# [100 rows x 3 columns]
