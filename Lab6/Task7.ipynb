# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df_country = pd.read_csv("https://raw.githubusercontent.com/sagihaider/CE888_2021/main/Lab_6/Data/Country-data.csv")
df_dictionary = pd.read_csv("https://raw.githubusercontent.com/sagihaider/CE888_2021/main/Lab_6/Data/data-dictionary.csv")

# %%
df_country
# Out:
#                  country  child_mort  exports  ...  life_expec  total_fer   gdpp
# 0            Afghanistan        90.2     10.0  ...        56.2       5.82    553
# 1                Albania        16.6     28.0  ...        76.3       1.65   4090
# 2                Algeria        27.3     38.4  ...        76.5       2.89   4460
# 3                 Angola       119.0     62.3  ...        60.1       6.16   3530
# 4    Antigua and Barbuda        10.3     45.5  ...        76.8       2.13  12200
# ..                   ...         ...      ...  ...         ...        ...    ...
# 162              Vanuatu        29.2     46.6  ...        63.0       3.50   2970
# 163            Venezuela        17.1     28.5  ...        75.4       2.47  13500
# 164              Vietnam        23.3     72.0  ...        73.1       1.95   1310
# 165                Yemen        56.3     30.0  ...        67.5       4.67   1310
# 166               Zambia        83.1     37.0  ...        52.0       5.40   1460
#
# ...

# %%
X = df_country.iloc[:,1:]
X
# Out:
#      child_mort  exports  health  ...  life_expec  total_fer   gdpp
# 0          90.2     10.0    7.58  ...        56.2       5.82    553
# 1          16.6     28.0    6.55  ...        76.3       1.65   4090
# 2          27.3     38.4    4.17  ...        76.5       2.89   4460
# 3         119.0     62.3    2.85  ...        60.1       6.16   3530
# 4          10.3     45.5    6.03  ...        76.8       2.13  12200
# ..          ...      ...     ...  ...         ...        ...    ...
# 162        29.2     46.6    5.25  ...        63.0       3.50   2970
# 163        17.1     28.5    4.91  ...        75.4       2.47  13500
# 164        23.3     72.0    6.84  ...        73.1       1.95   1310
# 165        56.3     30.0    5.18  ...        67.5       4.67   1310
# 166        83.1     37.0    5.89  ...        52.0       5.40   1460
#
# [167 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_std = sc.fit_transform(X)

# %% [markdown]
# **Apply PCA with n_components=3 on X_train_std data**

# %%
pca = PCA(n_components=9)
X_train_pca = pca.fit_transform(X_train_std)

# %%
#X_train_pca

# %% [markdown]
# K_means clustering to cluster the data

# %%
from sklearn import cluster, datasets, metrics
km=cluster.KMeans(n_clusters=3)
km.fit(X_train_pca)
label = km.labels_

# %% [markdown]
# Now, check range of income

# %%
df_country['labels']=list(label)

# %%
df_country[df_country['labels']==2]
# Out:
#                   country  child_mort  exports  ...  total_fer    gdpp  labels
# 7               Australia         4.8     19.8  ...       1.93   51900       2
# 8                 Austria         4.3     51.3  ...       1.44   46900       2
# 11                Bahrain         8.6     69.5  ...       2.16   20700       2
# 15                Belgium         4.5     76.4  ...       1.86   44400       2
# 23                 Brunei        10.5     67.4  ...       1.84   35300       2
# 29                 Canada         5.6     29.1  ...       1.63   47400       2
# 42                 Cyprus         3.6     50.2  ...       1.42   30800       2
# 43         Czech Republic         3.4     66.0  ...       1.51   19800       2
# 44                Denmark         4.1     50.5  ...       1.87   58000       2
# 53                Finland         3.0     38.7  ...       1.87   46200       2
# 54                 France         4.2     26.8  ...       2.03   40600       2
# ...

# %%
df_country[df_country['labels']==1]
# Out:
#                  country  child_mort  exports  ...  total_fer   gdpp  labels
# 1                Albania        16.6     28.0  ...       1.65   4090       1
# 2                Algeria        27.3     38.4  ...       2.89   4460       1
# 4    Antigua and Barbuda        10.3     45.5  ...       2.13  12200       1
# 5              Argentina        14.5     18.9  ...       2.37  10300       1
# 6                Armenia        18.1     20.8  ...       1.69   3220       1
# ..                   ...         ...      ...  ...        ...    ...     ...
# 160              Uruguay        10.6     26.3  ...       2.08  11900       1
# 161           Uzbekistan        36.3     31.7  ...       2.34   1380       1
# 162              Vanuatu        29.2     46.6  ...       3.50   2970       1
# 163            Venezuela        17.1     28.5  ...       2.47  13500       1
# 164              Vietnam        23.3     72.0  ...       1.95   1310       1
#
# [84 rows x 11 columns]

# %%
df_country[df_country['labels']==2]
#df_1[df_1['country']=='India']
#developed
# Out:
#                   country  child_mort  exports  ...  total_fer    gdpp  labels
# 7               Australia         4.8     19.8  ...       1.93   51900       2
# 8                 Austria         4.3     51.3  ...       1.44   46900       2
# 11                Bahrain         8.6     69.5  ...       2.16   20700       2
# 15                Belgium         4.5     76.4  ...       1.86   44400       2
# 23                 Brunei        10.5     67.4  ...       1.84   35300       2
# 29                 Canada         5.6     29.1  ...       1.63   47400       2
# 42                 Cyprus         3.6     50.2  ...       1.42   30800       2
# 43         Czech Republic         3.4     66.0  ...       1.51   19800       2
# 44                Denmark         4.1     50.5  ...       1.87   58000       2
# 53                Finland         3.0     38.7  ...       1.87   46200       2
# 54                 France         4.2     26.8  ...       2.03   40600       2
# ...

# %%
df_country[df_country['labels']==2].count()
# Out:
# country       36
# child_mort    36
# exports       36
# health        36
# imports       36
# income        36
# inflation     36
# life_expec    36
# total_fer     36
# gdpp          36
# labels        36
# dtype: int64

# %% [markdown]
# We know that there are only few developed countries in the world. There are total 36 ountries with label 2 and countries like USA, UK, Australia, UAE, Switzerland etc are marked as label 2. Therefore we can infer that countries marked as label 2 are classified as "**Developed**"

# %%
(df_country[df_country['labels']==1]).sort_values(by=['gdpp']) 
#df_1 =

 #df_country[df_country['labels']==1]
#df_1[df_1['country']=='India']

# developing
# Out:
#              country  child_mort  exports  ...  total_fer   gdpp  labels
# 109            Nepal        47.0     9.58  ...       2.61    592       1
# 146       Tajikistan        52.4    14.90  ...       3.51    738       1
# 12        Bangladesh        49.4    16.00  ...       2.33    758       1
# 27          Cambodia        44.4    54.10  ...       2.88    786       1
# 83   Kyrgyz Republic        29.6    51.60  ...       3.10    880       1
# ..               ...         ...      ...  ...        ...    ...     ...
# 51           Estonia         4.5    75.10  ...       1.72  14600       1
# 13          Barbados        14.2    39.50  ...       1.78  16000       1
# 115             Oman        11.7    65.70  ...       2.90  19300       1
# 128     Saudi Arabia        15.7    49.60  ...       2.96  19300       1
# 10           Bahamas        13.8    35.00  ...       1.86  28000       1
#
# [84 rows x 11 columns]

# %%
df_1 =df_country[df_country['labels']==1]
df_1[df_1['country']=='India']
# Out:
#    country  child_mort  exports  health  ...  life_expec  total_fer  gdpp  labels
# 69   India        58.8     22.6    4.05  ...        66.2        2.6  1350       1
#
# [1 rows x 11 columns]

# %% [markdown]
# Similar to how we derived label 2 as Developed we can infer from the dataframe that label 1 represents "**Developing**" countries.

# %%
(df_country[df_country['labels']==0]).sort_values(by=['gdpp']) 
#Under-developing
# Out:
#                       country  child_mort  exports  ...  total_fer   gdpp  labels
# 26                    Burundi        93.6     8.92  ...       6.26    231       0
# 88                    Liberia        89.3    19.10  ...       5.02    327       0
# 37           Congo, Dem. Rep.       116.0    41.10  ...       6.54    334       0
# 112                     Niger       123.0    22.20  ...       7.49    348       0
# 132              Sierra Leone       160.0    16.80  ...       5.20    399       0
# 93                 Madagascar        62.2    25.00  ...       4.60    413       0
# 106                Mozambique       101.0    31.50  ...       5.56    419       0
# 31   Central African Republic       149.0    11.80  ...       5.21    446       0
# 94                     Malawi        90.5    22.80  ...       5.31    459       0
# 50                    Eritrea        55.2     4.79  ...       4.61    482       0
# ...

# %% [markdown]
# In the above result, we can see that countries marked as label 0 are under-developing countries.
